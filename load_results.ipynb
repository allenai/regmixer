# %%
import wandb

# Initialize API
api = wandb.Api()

# Replace with your project name and run ID
project_name = "regmixer"
run_id = "pt9bj68g"

# Fetch the run
run = api.run(f"{project_name}/{run_id}")

# Get all metric names that start with "eval/downstream"
eval_downstream_metrics = [k for k in run.summary.keys() if k.startswith("eval/downstream")]

# Print the metric names
print(eval_downstream_metrics)
# Out:
# ['eval/downstream/arc_challenge (BPB)', 'eval/downstream/arc_challenge (CE loss)', 'eval/downstream/arc_challenge (length-normalized accuracy)', 'eval/downstream/arc_challenge (log soft loss)', 'eval/downstream/arc_challenge (soft loss)', 'eval/downstream/arc_challenge_mc_5shot (BPB)', 'eval/downstream/arc_challenge_mc_5shot (CE loss)', 'eval/downstream/arc_challenge_mc_5shot (accuracy)', 'eval/downstream/arc_challenge_mc_5shot (log soft loss)', 'eval/downstream/arc_challenge_mc_5shot (soft loss)', 'eval/downstream/arc_challenge_mc_5shot_bpb (BPB)', 'eval/downstream/arc_challenge_rc_5shot (BPB)', 'eval/downstream/arc_challenge_rc_5shot (CE loss)', 'eval/downstream/arc_challenge_rc_5shot (length-normalized accuracy)', 'eval/downstream/arc_challenge_rc_5shot (log soft loss)', 'eval/downstream/arc_challenge_rc_5shot (soft loss)', 'eval/downstream/arc_challenge_rc_5shot_bpb (BPB)', 'eval/downstream/arc_easy (BPB)', 'eval/downstream/arc_easy (CE loss)', 'eval/downstream/arc_easy (accuracy)', 'eval/downstream/arc_easy (log soft loss)', 'eval/downstream/arc_easy (soft loss)', 'eval/downstream/arc_easy_mc_5shot (BPB)', 'eval/downstream/arc_easy_mc_5shot (CE loss)', 'eval/downstream/arc_easy_mc_5shot (accuracy)', 'eval/downstream/arc_easy_mc_5shot (log soft loss)', 'eval/downstream/arc_easy_mc_5shot (soft loss)', 'eval/downstream/arc_easy_mc_5shot_bpb (BPB)', 'eval/downstream/arc_easy_ppl (CE loss)', 'eval/downstream/arc_easy_rc_5shot (BPB)', 'eval/downstream/arc_easy_rc_5shot (CE loss)', 'eval/downstream/arc_easy_rc_5shot (accuracy)', 'eval/downstream/arc_easy_rc_5shot (log soft loss)', 'eval/downstream/arc_easy_rc_5shot (soft loss)', 'eval/downstream/arc_easy_rc_5shot_bpb (BPB)', 'eval/downstream/basic_arithmetic (BPB)', 'eval/downstream/basic_arithmetic (CE loss)', 'eval/downstream/basic_arithmetic (accuracy)', 'eval/downstream/basic_arithmetic (log soft loss)', 'eval/downstream/basic_arithmetic (soft loss)', 'eval/downstream/boolq (BPB)', 'eval/downstream/boolq (CE loss)', 'eval/downstream/boolq (accuracy)', 'eval/downstream/boolq (log soft loss)', 'eval/downstream/boolq (soft loss)', 'eval/downstream/boolq_mc_5shot (BPB)', 'eval/downstream/boolq_mc_5shot (CE loss)', 'eval/downstream/boolq_mc_5shot (accuracy)', 'eval/downstream/boolq_mc_5shot (log soft loss)', 'eval/downstream/boolq_mc_5shot (soft loss)', 'eval/downstream/boolq_mc_5shot_bpb (BPB)', 'eval/downstream/boolq_rc_5shot (BPB)', 'eval/downstream/boolq_rc_5shot (CE loss)', 'eval/downstream/boolq_rc_5shot (accuracy)', 'eval/downstream/boolq_rc_5shot (log soft loss)', 'eval/downstream/boolq_rc_5shot (soft loss)', 'eval/downstream/boolq_rc_5shot_bpb (BPB)', 'eval/downstream/commonsense_qa (BPB)', 'eval/downstream/commonsense_qa (CE loss)', 'eval/downstream/commonsense_qa (length-normalized accuracy)', 'eval/downstream/commonsense_qa (log soft loss)', 'eval/downstream/commonsense_qa (soft loss)', 'eval/downstream/copa (BPB)', 'eval/downstream/copa (CE loss)', 'eval/downstream/copa (accuracy)', 'eval/downstream/copa (log soft loss)', 'eval/downstream/copa (soft loss)', 'eval/downstream/csqa_mc_5shot (BPB)', 'eval/downstream/csqa_mc_5shot (CE loss)', 'eval/downstream/csqa_mc_5shot (accuracy)', 'eval/downstream/csqa_mc_5shot (log soft loss)', 'eval/downstream/csqa_mc_5shot (soft loss)', 'eval/downstream/csqa_mc_5shot_bpb (BPB)', 'eval/downstream/csqa_rc_5shot (BPB)', 'eval/downstream/csqa_rc_5shot (CE loss)', 'eval/downstream/csqa_rc_5shot (length-normalized accuracy)', 'eval/downstream/csqa_rc_5shot (log soft loss)', 'eval/downstream/csqa_rc_5shot (soft loss)', 'eval/downstream/csqa_rc_5shot_bpb (BPB)', 'eval/downstream/hellaswag (BPB)', 'eval/downstream/hellaswag (CE loss)', 'eval/downstream/hellaswag (length-normalized accuracy)', 'eval/downstream/hellaswag (log soft loss)', 'eval/downstream/hellaswag (soft loss)', 'eval/downstream/hellaswag_mc_5shot (BPB)', 'eval/downstream/hellaswag_mc_5shot (CE loss)', 'eval/downstream/hellaswag_mc_5shot (accuracy)', 'eval/downstream/hellasw ...

# %%
{k: run.summary[k] for k in eval_downstream_metrics}
# Out:
# {'eval/downstream/arc_challenge (BPB)': 2.252821922302246,
#  'eval/downstream/arc_challenge (CE loss)': 1.5615724325180054,
#  'eval/downstream/arc_challenge (length-normalized accuracy)': 0.2040133774280548,
#  'eval/downstream/arc_challenge (log soft loss)': -1.416715145111084,
#  'eval/downstream/arc_challenge (soft loss)': 0.2532850503921509,
#  'eval/downstream/arc_challenge_mc_5shot (BPB)': 4.161789417266846,
#  'eval/downstream/arc_challenge_mc_5shot (CE loss)': 2.8847720623016357,
#  'eval/downstream/arc_challenge_mc_5shot (accuracy)': 0.21739129722118378,
#  'eval/downstream/arc_challenge_mc_5shot (log soft loss)': -1.6992669105529785,
#  'eval/downstream/arc_challenge_mc_5shot (soft loss)': 0.23509830236434937,
#  'eval/downstream/arc_challenge_mc_5shot_bpb (BPB)': 4.161789417266846,
#  'eval/downstream/arc_challenge_rc_5shot (BPB)': 2.071514368057251,
#  'eval/downstream/arc_challenge_rc_5shot (CE loss)': 1.4361021518707275,
#  'eval/downstream/arc_challenge_rc_5shot (length-normalized accuracy)': 0.2441471517086029,
#  'eval/downstream/arc_challenge_rc_5shot (log soft loss)': -1.4158954620361328,
#  'eval/downstream/arc_challenge_rc_5shot (soft loss)': 0.25202757120132446,
#  'eval/downstream/arc_challenge_rc_5shot_bpb (BPB)': 2.071514368057251,
#  'eval/downstream/arc_easy (BPB)': 2.514521598815918,
#  'eval/downstream/arc_easy (CE loss)': 1.7429276704788208,
#  'eval/downstream/arc_easy (accuracy)': 0.27368420362472534,
#  'eval/downstream/arc_easy (log soft loss)': -5.620643615722656,
#  'eval/downstream/arc_easy (soft loss)': 0.268864244222641,
#  'eval/downstream/arc_easy_mc_5shot (BPB)': 4.091214179992676,
#  'eval/downstream/arc_easy_mc_5shot (CE loss)': 2.8361294269561768,
#  'eval/downstream/arc_easy_mc_5shot (accuracy)': 0.27719298005104065,
#  'eval/downstream/arc_easy_mc_5shot (log soft loss)': -1.534217119216919,
#  'eval/downstream/arc_easy_mc_5shot (soft loss)': 0.25990647077560425,
#  'eval/downstream/arc_easy_mc_5shot_bpb (BPB)': 4.091214179992676,
#  'eval/downstream/arc_easy_ppl (CE loss)': 1.821792721748352,
#  'eval/downstream/arc_easy_rc_5shot (BPB)': 2.2888705730438232,
#  'eval/downstream/arc_easy_rc_5shot (CE loss)': 1.5866022109985352,
#  'eval/downstream/arc_easy_rc_5shot (accuracy)': 0.2666666805744171,
#  'eval/downstream/arc_easy_rc_5shot (log soft loss)': -5.445229530334473,
#  'eval/downstream/arc_easy_rc_5shot (soft loss)': 0.2682916522026062,
#  'eval/downstream/arc_easy_rc_5shot_bpb (BPB)': 2.2888705730438232,
#  'eval/downstream/basic_arithmetic (BPB)': 6.013989448547363,
#  'eval/downstream/basic_arithmetic (CE loss)': 4.168460845947266,
#  'eval/downstream/basic_arithmetic (accuracy)': 0.2226666659116745,
#  'eval/downstream/basic_arithmetic (log soft loss)': -2.535061836242676,
#  'eval/downstream/basic_arithmetic (soft loss)': 0.22048057615756989,
#  'eval/downstream/boolq (BPB)': 3.3148820400238037,
#  'eval/downstream/boolq (CE loss)': 2.2977278232574463,
#  'eval/downstream/boolq (accuracy)': 0.48103976249694824,
#  'eval/downstream/boolq (log soft loss)': -0.7440627217292786,
#  'eval/downstream/boolq (soft loss)': 0.4895821809768677,
#  'eval/downstream/boolq_mc_5shot (BPB)': 3.7770156860351562,
#  'eval/downstream/boolq_mc_5shot (CE loss)': 2.6181561946868896,
#  'eval/downstream/boolq_mc_5shot (accuracy)': 0.6380000114440918,
#  'eval/downstream/boolq_mc_5shot (log soft loss)': -0.6721659302711487,
#  'eval/downstream/boolq_mc_5shot (soft loss)': 0.5585258603096008,
#  'eval/downstream/boolq_mc_5shot_bpb (BPB)': 3.7770156860351562,
#  'eval/downstream/boolq_rc_5shot (BPB)': 1.0091015100479126,
#  'eval/downstream/boolq_rc_5shot (CE loss)': 0.699267566204071,
#  'eval/downstream/boolq_rc_5shot (accuracy)': 0.6349999904632568,
#  'eval/downstream/boolq_rc_5shot (log soft loss)': -0.6653006076812744,
#  'eval/downstream/boolq_rc_5shot (soft loss)': 0.523712158203125,
#  'eval/downstream/boolq_rc_5shot_bpb (BPB)': 1.0091015100479126,
#  'eval/downstream/commonsense_qa (BPB)': 2.828355312347412,
#  'eval/downstream/commonsense_qa (CE loss)': 1.9604160785675049,
#  'eval/downstream/commonsense_qa (length-normalized accuracy)': 0.23751023411750793,
#  'eval/downstream/commonsense_qa (log soft loss)': -1.6716302633285522,
#  'eval/downstream/commonsense_qa (soft loss)': 0.21901772916316986,
#  'eval/downstream/copa (BPB)': 1.5716406106948853,
#  'eval/downstream/copa (CE loss)': 1.0895702838897705,
#  'eval/downstream/copa (accuracy)': 0.5199999809265137,
#  'eval/downstream/copa (log soft loss)': -2.2256290912628174,
#  'eval/downstream/copa (soft loss)': 0.525398313999176,
#  'eval/downstream/csqa_mc_5shot (BPB)': 4.774096488952637,
#  'eval/downstream/csqa_mc_5shot (CE loss)': 3.3089168071746826,
#  'eval/downstream/csqa_mc_5shot (accuracy)': 0.1957411915063858,
#  'eval/downstream/csqa_mc_5shot (log soft loss)': -1.9011181592941284,
#  'eval/downstream/csqa_mc_5shot (soft loss)': 0.19944044947624207,
#  'eval/downstream/csqa_mc_5shot_bpb (BPB)': 4.774096488952637,
#  'eval/downstream/csqa_rc_5shot (BPB)': 2.43546199798584,
#  'eval/downstream/csqa_rc_5shot (CE loss)': 1.688117504119873,
#  'eval/downstream/csqa_rc_5shot (length-normalized accuracy)': 0.24488124251365662,
#  'eval/downstream/csqa_rc_5shot (log soft loss)': -1.6531496047973633,
#  'eval/downstream/csqa_rc_5shot (soft loss)': 0.21640565991401672,
#  'eval/downstream/csqa_rc_5shot_bpb (BPB)': 2.43546199798584,
#  'eval/downstream/hellaswag (BPB)': 1.4638949632644653,
#  'eval/downstream/hellaswag (CE loss)': 1.0147048234939575,
#  'eval/downstream/hellaswag (length-normalized accuracy)': 0.25413262844085693,
#  'eval/downstream/hellaswag (log soft loss)': -1.3930747509002686,
#  'eval/downstream/hellaswag (soft loss)': 0.25069770216941833,
#  'eval/downstream/hellaswag_mc_5shot (BPB)': 4.611859321594238,
#  'eval/downstream/hellaswag_mc_5shot (CE loss)': 3.196601629257202,
#  'eval/downstream/hellaswag_mc_5shot (accuracy)': 0.2590000033378601,
#  'eval/downstream/hellaswag_mc_5shot (log soft loss)': -1.49168062210083,
#  'eval/downstream/hellaswag_mc_5shot (soft loss)': 0.25170600414276123,
#  'eval/downstream/hellaswag_mc_5shot_bpb (BPB)': 4.611859321594238,
#  'eval/downstream/hellaswag_rc_5shot (BPB)': 1.4486445188522339,
#  'eval/downstream/hellaswag_rc_5shot (CE loss)': 1.0041855573654175,
#  'eval/downstream/hellaswag_rc_5shot (length-normalized accuracy)': 0.24699999392032623,
#  'eval/downstream/hellaswag_rc_5shot (log soft loss)': -1.393968939781189,
#  'eval/downstream/hellaswag_rc_5shot (soft loss)': 0.25051140785217285,
#  'eval/downstream/hellaswag_rc_5shot_bpb (BPB)': 1.4486445188522339,
#  'eval/downstream/mmlu_humanities_bpb (BPB)': 2.145458698272705,
#  'eval/downstream/mmlu_humanities_mc_5shot (BPB)': 5.003303050994873,
#  'eval/downstream/mmlu_humanities_mc_5shot (CE loss)': 3.4680185317993164,
#  'eval/downstream/mmlu_humanities_mc_5shot (length-normalized accuracy)': 0.2277992218732834,
#  'eval/downstream/mmlu_humanities_mc_5shot (log soft loss)': -2.1891939640045166,
#  'eval/downstream/mmlu_humanities_mc_5shot (soft loss)': 0.23667839169502258,
#  'eval/downstream/mmlu_humanities_mc_5shot_test (BPB)': 4.971195220947266,
#  'eval/downstream/mmlu_humanities_mc_5shot_test (CE loss)': 3.4460606575012207,
#  'eval/downstream/mmlu_humanities_mc_5shot_test (length-normalized accuracy)': 0.23783209919929504,
#  'eval/downstream/mmlu_humanities_mc_5shot_test (log soft loss)': -2.1675784587860107,
#  'eval/downstream/mmlu_humanities_mc_5shot_test (soft loss)': 0.2434822916984558,
#  'eval/downstream/mmlu_humanities_var (BPB)': 2.045783758163452,
#  'eval/downstream/mmlu_humanities_var (CE loss)': 1.4290766716003418,
#  'eval/downstream/mmlu_humanities_var (length-normalized accuracy)': 0.2597903907299042,
#  'eval/downstream/mmlu_humanities_var (log soft loss)': -1.4577606916427612,
#  'eval/downstream/mmlu_humanities_var (soft loss)': 0.24433209002017975,
#  'eval/downstream/mmlu_humanities_var_bpb (BPB)': 2.045783758163452,
#  'eval/downstream/mmlu_other_bpb (BPB)': 2.885343313217163,
#  'eval/downstream/mmlu_other_mc_5shot (BPB)': 4.108428478240967,
#  'eval/downstream/mmlu_other_mc_5shot (CE loss)': 2.8478102684020996,
#  'eval/downstream/mmlu_other_mc_5shot (length-normalized accuracy)': 0.25915491580963135,
#  'eval/downstream/mmlu_other_mc_5shot (log soft loss)': -1.691269874572754,
#  'eval/downstream/mmlu_other_mc_5shot (soft loss)': 0.251506507396698,
#  'eval/downstream/mmlu_other_mc_5shot_test (BPB)': 4.05849027633667,
#  'eval/downstream/mmlu_other_mc_5shot_test (CE loss)': 2.8129494190216064,
#  'eval/downstream/mmlu_other_mc_5shot_test (length-normalized accuracy)': 0.2760641574859619,
#  'eval/downstream/mmlu_other_mc_5shot_test (log soft loss)': -1.6616086959838867,
#  'eval/downstream/mmlu_other_mc_5shot_test (soft loss)': 0.26029136776924133,
#  'eval/downstream/mmlu_other_var (BPB)': 2.809536933898926,
#  'eval/downstream/mmlu_other_var (CE loss)': 1.9475493431091309,
#  'eval/downstream/mmlu_other_var (length-normalized accuracy)': 0.2627766728401184,
#  'eval/downstream/mmlu_other_var (log soft loss)': -1.4607595205307007,
#  'eval/downstream/mmlu_other_var (soft loss)': 0.2537519037723541,
#  'eval/downstream/mmlu_other_var_bpb (BPB)': 2.8095242977142334,
#  'eval/downstream/mmlu_social_sciences_bpb (BPB)': 1.9897069931030273,
#  'eval/downstream/mmlu_social_sciences_mc_5shot (BPB)': 4.171619892120361,
#  'eval/downstream/mmlu_social_sciences_mc_5shot (CE loss)': 2.891587018966675,
#  'eval/downstream/mmlu_social_sciences_mc_5shot (length-normalized accuracy)': 0.2611275911331177,
#  'eval/downstream/mmlu_social_sciences_mc_5shot (log soft loss)': -1.6823168992996216,
#  'eval/downstream/mmlu_social_sciences_mc_5shot (soft loss)': 0.2522544860839844,
#  'eval/downstream/mmlu_social_sciences_mc_5shot_test (BPB)': 4.2077789306640625,
#  'eval/downstream/mmlu_social_sciences_mc_5shot_test (CE loss)': 2.9164657592773438,
#  'eval/downstream/mmlu_social_sciences_mc_5shot_test (length-normalized accuracy)': 0.24276892840862274,
#  'eval/downstream/mmlu_social_sciences_mc_5shot_test (log soft loss)': -1.7074201107025146,
#  'eval/downstream/mmlu_social_sciences_mc_5shot_test (soft loss)': 0.2440664917230606,
#  'eval/downstream/mmlu_social_sciences_var (BPB)': 1.9414211511611938,
#  'eval/downstream/mmlu_social_sciences_var (CE loss)': 1.3468713760375977,
#  'eval/downstream/mmlu_social_sciences_var (length-normalized accuracy)': 0.2700296640396118,
#  'eval/downstream/mmlu_social_sciences_var (log soft loss)': -1.4304691553115845,
#  'eval/downstream/mmlu_social_sciences_var (soft loss)': 0.2505486011505127,
#  'eval/downstream/mmlu_social_sciences_var_bpb (BPB)': 1.9414211511611938,
#  'eval/downstream/mmlu_stem_bpb (BPB)': 3.845794439315796,
#  'eval/downstream/mmlu_stem_mc_5shot (BPB)': 4.22635555267334,
#  'eval/downstream/mmlu_stem_mc_5shot (CE loss)': 2.9300646781921387,
#  'eval/downstream/mmlu_stem_mc_5shot (length-normalized accuracy)': 0.23676012456417084,
#  'eval/downstream/mmlu_stem_mc_5shot (log soft loss)': -1.8056272268295288,
#  'eval/downstream/mmlu_stem_mc_5shot (soft loss)': 0.24536611139774323,
#  'eval/downstream/mmlu_stem_mc_5shot_test (BPB)': 4.219846248626709,
#  'eval/downstream/mmlu_stem_mc_5shot_test (CE loss)': 2.925126314163208,
#  'eval/downstream/mmlu_stem_mc_5shot_test (length-normalized accuracy)': 0.263750821352005,
#  'eval/downstream/mmlu_stem_mc_5shot_test (log soft loss)': -1.7894384860992432,
#  'eval/downstream/mmlu_stem_mc_5shot_test (soft loss)': 0.2548805773258209,
#  'eval/downstream/mmlu_stem_var (BPB)': 3.7066783905029297,
#  'eval/downstream/mmlu_stem_var (CE loss)': 2.59480357170105,
#  'eval/downstream/mmlu_stem_var (length-normalized accuracy)': 0.2621272802352905,
#  'eval/downstream/mmlu_stem_var (log soft loss)': -1.5060653686523438,
#  'eval/downstream/mmlu_stem_var (soft loss)': 0.2480093091726303,
#  'eval/downstream/mmlu_stem_var_bpb (BPB)': 3.7066783905029297,
#  'eval/downstream/natural_qs_open_ppl (CE loss)': 2.215585947036743,
#  'eval/downstream/openbook_qa (BPB)': 2.5310781002044678,
#  'eval/downstream/openbook_qa (CE loss)': 1.754453182220459,
#  'eval/downstream/openbook_qa (length-normalized accuracy)': 0.25600001215934753,
#  'eval/downstream/openbook_qa (log soft loss)': -1.5043785572052002,
#  'eval/downstream/openbook_qa (soft loss)': 0.24224574863910675,
#  'eval/downstream/openbookqa_mc_5shot (BPB)': 4.1569061279296875,
#  'eval/downstream/openbookqa_mc_5shot (CE loss)': 2.881453037261963,
#  'eval/downstream/openbookqa_mc_5shot (accuracy)': 0.2540000081062317,
#  'eval/downstream/openbookqa_mc_5shot (log soft loss)': -1.5240223407745361,
#  'eval/downstream/openbookqa_mc_5shot (soft loss)': 0.25328338146209717,
#  'eval/downstream/openbookqa_mc_5shot_bpb (BPB)': 4.1569061279296875,
#  'eval/downstream/openbookqa_rc_5shot (BPB)': 2.4457812309265137,
#  'eval/downstream/openbookqa_rc_5shot (CE loss)': 1.6951249837875366,
#  'eval/downstream/openbookqa_rc_5shot (length-normalized accuracy)': 0.22200000286102295,
#  'eval/downstream/openbookqa_rc_5shot (log soft loss)': -1.50028395652771,
#  'eval/downstream/openbookqa_rc_5shot (soft loss)': 0.2409433275461197,
#  'eval/downstream/openbookqa_rc_5shot_bpb (BPB)': 2.4457812309265137,
#  'eval/downstream/piqa (BPB)': 1.9032363891601562,
#  'eval/downstream/piqa (CE loss)': 1.319606900215149,
#  'eval/downstream/piqa (length-normalized accuracy)': 0.5228509306907654,
#  'eval/downstream/piqa (log soft loss)': -0.6992259621620178,
#  'eval/downstream/piqa (soft loss)': 0.49942746758461,
#  'eval/downstream/piqa_mc_5shot (BPB)': 2.9555156230926514,
#  'eval/downstream/piqa_mc_5shot (CE loss)': 2.048281192779541,
#  'eval/downstream/piqa_mc_5shot (accuracy)': 0.4860000014305115,
#  'eval/downstream/piqa_mc_5shot (log soft loss)': -0.7180006504058838,
#  'eval/downstream/piqa_mc_5shot (soft loss)': 0.49599936604499817,
#  'eval/downstream/piqa_mc_5shot_bpb (BPB)': 2.9555156230926514,
#  'eval/downstream/piqa_rc_5shot (BPB)': 1.8487616777420044,
#  'eval/downstream/piqa_rc_5shot (CE loss)': 1.2816835641860962,
#  'eval/downstream/piqa_rc_5shot (length-normalized accuracy)': 0.5009999871253967,
#  'eval/downstream/piqa_rc_5shot (log soft loss)': -0.7045994400978088,
#  'eval/downstream/piqa_rc_5shot (soft loss)': 0.4966033101081848,
#  'eval/downstream/piqa_rc_5shot_bpb (BPB)': 1.8487616777420044,
#  'eval/downstream/sciq (BPB)': 2.9716954231262207,
#  'eval/downstream/sciq (CE loss)': 2.059792995452881,
#  'eval/downstream/sciq (accuracy)': 0.24400000274181366,
#  'eval/downstream/sciq (log soft loss)': -4.225612640380859,
#  'eval/downstream/sciq (soft loss)': 0.25112810730934143,
#  'eval/downstream/social_iqa (BPB)': 2.096055030822754,
#  'eval/downstream/social_iqa (CE loss)': 1.4528831243515015,
#  'eval/downstream/social_iqa (length-normalized accuracy)': 0.39713409543037415,
#  'eval/downstream/social_iqa (log soft loss)': -1.1197260618209839,
#  'eval/downstream/social_iqa (soft loss)': 0.3481178283691406,
#  'eval/downstream/socialiqa_mc_5shot (BPB)': 5.069031238555908,
#  'eval/downstream/socialiqa_mc_5shot (CE loss)': 3.5135157108306885,
#  'eval/downstream/socialiqa_mc_5shot (accuracy)': 0.3269999921321869,
#  'eval/downstream/socialiqa_mc_5shot (log soft loss)': -1.233185887336731,
#  'eval/downstream/socialiqa_mc_5shot (soft loss)': 0.3306839168071747,
#  'eval/downstream/socialiqa_mc_5shot_bpb (BPB)': 5.069031238555908,
#  'eval/downstream/socialiqa_rc_5shot (BPB)': 1.9894648790359497,
#  'eval/downstream/socialiqa_rc_5shot (CE loss)': 1.3791054487228394,
#  'eval/downstream/socialiqa_rc_5shot (length-normalized accuracy)': 0.3840000033378601,
#  'eval/downstream/socialiqa_rc_5shot (log soft loss)': -1.1175822019577026,
#  'eval/downstream/socialiqa_rc_5shot (soft loss)': 0.34433022141456604,
#  'eval/downstream/socialiqa_rc_5shot_bpb (BPB)': 1.9894648790359497,
#  'eval/downstream/trivia_qa_wiki_ppl (CE loss)': 2.5402138233184814,
#  'eval/downstream/winogrande (BPB)': 1.8554317951202393,
#  'eval/downstream/winogrande (CE loss)': 1.2859408855438232,
#  'eval/downstream/winogrande (accuracy)': 0.4988161027431488,
#  'eval/downstream/winogrande (log soft loss)': -0.858704149723053,
#  'eval/downstream/winogrande (soft loss)': 0.4948188364505768,
#  'eval/downstream/winogrande_mc_5shot (BPB)': 2.250875473022461,
#  'eval/downstream/winogrande_mc_5shot (CE loss)': 1.5600119829177856,
#  'eval/downstream/winogrande_mc_5shot (accuracy)': 0.4956590235233307,
#  'eval/downstream/winogrande_mc_5shot (log soft loss)': -0.7439232468605042,
#  'eval/downstream/winogrande_mc_5shot (soft loss)': 0.4990646243095398,
#  'eval/downstream/winogrande_mc_5shot_bpb (BPB)': 2.250875473022461,
#  'eval/downstream/winogrande_rc_5shot (BPB)': 1.8152531385421753,
#  'eval/downstream/winogrande_rc_5shot (CE loss)': 1.2581146955490112,
#  'eval/downstream/winogrande_rc_5shot (accuracy)': 0.4932912290096283,
#  'eval/downstream/winogrande_rc_5shot (log soft loss)': -0.8045297861099243,
#  'eval/downstream/winogrande_rc_5shot (soft loss)': 0.4988798499107361,
#  'eval/downstream/winogrande_rc_5shot_bpb (BPB)': 1.8152531385421753}

# %%
eval_tasks = [metric.replace("eval/downstream/", "").split("(")[0].strip() for metric in eval_downstream_metrics]

# %%
import numpy as np
eval_tasks = np.unique(np.array(eval_tasks))

# %%
# For training runs where we don't expect the model to acquire MC (e.g., 1B-5xC, short 7B training runs)
tasks_small_compute = [
# OLMES Core 9(-ish) RC
"arc_challenge_test_rc_5shot",
"arc_easy_test_rc_5shot",
"hellaswag_rc_5shot", # 1K subset of HellaSwag
"winogrande_val_rc_5shot", # Helpful after 750M-5xC scale
"csqa_val_rc_5shot",
"piqa_val_rc_5shot",
"socialiqa_val_rc_5shot",

# Too noisy to be worth tracking
# "boolq_val_rc_5shot",
# "openbookqa_test_rc_5shot",

# MMLU RC
"mmlu_stem_val_rc_5shot",
"mmlu_humanities_val_rc_5shot",
"mmlu_social_sciences_val_rc_5shot",
"mmlu_other_val_rc_5shot",
"mmlu_stem_test_rc_5shot",
"mmlu_humanities_test_rc_5shot",
"mmlu_social_sciences_test_rc_5shot",
"mmlu_other_test_rc_5shot",

# Gen tasks BPB
"gsm8k_gold_bpb_5shot",
"minerva_math_algebra_gold_bpb_0shot",
"minerva_math_counting_and_probability_gold_bpb_0shot",
"minerva_math_geometry_gold_bpb_0shot",
"minerva_math_intermediate_algebra_gold_bpb_0shot",
"minerva_math_number_theory_gold_bpb_0shot",
"minerva_math_prealgebra_gold_bpb_0shot",
"minerva_math_precalculus_gold_bpb_0shot",
"codex_humaneval_gold_bpb_0shot",
"codex_mbpp_gold_bpb_0shot",

# Sanity check for MCQA ability
"copycolors_10way",
]

# For training runs where we expect the model to acquire MC
tasks_large_compute = [
# OLMES Core 9(-ish) MC
"arc_challenge_test_mc_5shot",
"arc_easy_test_mc_5shot",
"hellaswag_rc_5shot", # 1K subset of HellaSwag
"csqa_val_mc_5shot",
"piqa_val_mc_5shot",
"socialiqa_val_mc_5shot",
"winogrande_val_rc_5shot",

# Too noisy to be worth tracking
# "boolq_val_mc_5shot",
# "openbookqa_test_mc_5shot",

# MMLU MC BPB
"mmlu_stem_val_mc_5shot",
"mmlu_humanities_val_mc_5shot",
"mmlu_social_sciences_val_mc_5shot",
"mmlu_other_val_mc_5shot",
"mmlu_stem_test_mc_5shot",
"mmlu_humanities_test_mc_5shot",
"mmlu_social_sciences_test_mc_5shot",
"mmlu_other_test_mc_5shot",

# Gen tasks BPB
"gsm8k_gold_bpb_5shot",
"minerva_math_algebra_gold_bpb_0shot",
"minerva_math_counting_and_probability_gold_bpb_0shot",
"minerva_math_geometry_gold_bpb_0shot",
"minerva_math_intermediate_algebra_gold_bpb_0shot",
"minerva_math_number_theory_gold_bpb_0shot",
"minerva_math_prealgebra_gold_bpb_0shot",
"minerva_math_precalculus_gold_bpb_0shot",
"codex_humaneval_gold_bpb_0shot",
"codex_mbpp_gold_bpb_0shot",

# Sanity check for MCQA ability
"copycolors_10way",
]

# %%
tasks_small_compute = [task.replace("_test", "").replace("_val", "") for task in tasks_small_compute]

# %%
sorted(tasks_small_compute)
# Out:
# ['arc_challenge_rc_5shot',
#  'arc_easy_rc_5shot',
#  'codex_humaneval_gold_bpb_0shot',
#  'codex_mbpp_gold_bpb_0shot',
#  'copycolors_10way',
#  'csqa_rc_5shot',
#  'gsm8k_gold_bpb_5shot',
#  'hellaswag_rc_5shot',
#  'minerva_math_algebra_gold_bpb_0shot',
#  'minerva_math_counting_and_probability_gold_bpb_0shot',
#  'minerva_math_geometry_gold_bpb_0shot',
#  'minerva_math_intermediate_algebra_gold_bpb_0shot',
#  'minerva_math_number_theory_gold_bpb_0shot',
#  'minerva_math_prealgebra_gold_bpb_0shot',
#  'minerva_math_precalculus_gold_bpb_0shot',
#  'mmlu_humanities_rc_5shot',
#  'mmlu_humanities_rc_5shot',
#  'mmlu_other_rc_5shot',
#  'mmlu_other_rc_5shot',
#  'mmlu_social_sciences_rc_5shot',
#  'mmlu_social_sciences_rc_5shot',
#  'mmlu_stem_rc_5shot',
#  'mmlu_stem_rc_5shot',
#  'piqa_rc_5shot',
#  'socialiqa_rc_5shot',
#  'winogrande_rc_5shot']

# %%
sorted(eval_tasks)
# Out:
# ['arc_challenge',
#  'arc_challenge_mc_5shot',
#  'arc_challenge_mc_5shot_bpb',
#  'arc_challenge_rc_5shot',
#  'arc_challenge_rc_5shot_bpb',
#  'arc_easy',
#  'arc_easy_mc_5shot',
#  'arc_easy_mc_5shot_bpb',
#  'arc_easy_ppl',
#  'arc_easy_rc_5shot',
#  'arc_easy_rc_5shot_bpb',
#  'basic_arithmetic',
#  'boolq',
#  'boolq_mc_5shot',
#  'boolq_mc_5shot_bpb',
#  'boolq_rc_5shot',
#  'boolq_rc_5shot_bpb',
#  'commonsense_qa',
#  'copa',
#  'csqa_mc_5shot',
#  'csqa_mc_5shot_bpb',
#  'csqa_rc_5shot',
#  'csqa_rc_5shot_bpb',
#  'hellaswag',
#  'hellaswag_mc_5shot',
#  'hellaswag_mc_5shot_bpb',
#  'hellaswag_rc_5shot',
#  'hellaswag_rc_5shot_bpb',
#  'mmlu_humanities_bpb',
#  'mmlu_humanities_mc_5shot',
#  'mmlu_humanities_mc_5shot_test',
#  'mmlu_humanities_var',
#  'mmlu_humanities_var_bpb',
#  'mmlu_other_bpb',
#  'mmlu_other_mc_5shot',
#  'mmlu_other_mc_5shot_test',
#  'mmlu_other_var',
#  'mmlu_other_var_bpb',
#  'mmlu_social_sciences_bpb',
#  'mmlu_social_sciences_mc_5shot',
#  'mmlu_social_sciences_mc_5shot_test',
#  'mmlu_social_sciences_var',
#  'mmlu_social_sciences_var_bpb',
#  'mmlu_stem_bpb',
#  'mmlu_stem_mc_5shot',
#  'mmlu_stem_mc_5shot_test',
#  'mmlu_stem_var',
#  'mmlu_stem_var_bpb',
#  'natural_qs_open_ppl',
#  'openbook_qa',
#  'openbookqa_mc_5shot',
#  'openbookqa_mc_5shot_bpb',
#  'openbookqa_rc_5shot',
#  'openbookqa_rc_5shot_bpb',
#  'piqa',
#  'piqa_mc_5shot',
#  'piqa_mc_5shot_bpb',
#  'piqa_rc_5shot',
#  'piqa_rc_5shot_bpb',
#  'sciq',
#  'social_iqa',
#  'socialiqa_mc_5shot',
#  'socialiqa_mc_5shot_bpb',
#  'socialiqa_rc_5shot',
#  'socialiqa_rc_5shot_bpb',
#  'trivia_qa_wiki_ppl',
#  'winogrande',
#  'winogrande_mc_5shot',
#  'winogrande_mc_5shot_bpb',
#  'winogrande_rc_5shot',
#  'winogrande_rc_5shot_bpb']

# %%
sorted(set(tasks_small_compute).intersection(set(eval_tasks.tolist())))
# Out:
# ['arc_challenge_rc_5shot',
#  'arc_easy_rc_5shot',
#  'csqa_rc_5shot',
#  'hellaswag_rc_5shot',
#  'piqa_rc_5shot',
#  'socialiqa_rc_5shot',
#  'winogrande_rc_5shot']
