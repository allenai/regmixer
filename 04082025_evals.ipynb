# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd 
import numpy as np
import os
import json
from collections import defaultdict

from scipy.stats import spearmanr, pearsonr

from regmixer.synthesize_mixture import calculate_priors
from regmixer.utils import config_from_path
from regmixer.eval.utils import (
    build_regression,
    get_output_dir,
    get_runs_from_api,
    mk_run_from_json,
    mk_run_metrics,
    mk_weights_from_config,
    mk_output_prefix,
    plot_correlation,
    simulate2,
    )


import pathlib
import wandb
import boto3


from regmixer.eval.constants import GroupedWandbMetrics


from regmixer.eval.law import ScalingLaw

# %%
config = "src/regmixer/config/dclm-datadelve-5xC-30m-dolma2tok.yaml"
launch_config = config_from_path(config)


priors = calculate_priors(
        source_configs=launch_config.sources,
        dtype=launch_config.dtype,
        use_cache=False,
    )
# Out:
# Counting source tokens:   0%|          | 0/24 [00:00<?, ?it/s]2025-04-10 02:23:19,994 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:19,996 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-10 02:23:20,000 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:20,001 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:20,017 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 8
# 2025-04-10 02:23:20,060 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:20,061 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:21,562 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:21,563 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:21,565 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-10 02:23:21,566 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 8
# 2025-04-10 02:23:22,627 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:22,628 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:22,630 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:22,630 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:24,398 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:24,409 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 8
# 2025-04-10 02:23:24,409 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 8
# 2025-04-10 02:23:31,321 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:31,326 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-10 02:23:31,349 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:31,361 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-10 02:23:31,362 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 8
# 2025-04-10 02:23:31,591 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-10 02:23:31,594 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-10 02:23:31,601 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:34,644 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:34,652 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:34,653 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:34,654 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-10 02:23:39,988 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:39,997 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 7
# 2025-04-10 02:23:40,547 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:40,742 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-10 02:23:40,749 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 8
# 2025-04-10 02:23:43,160 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:43,162 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:43,166 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-10 02:23:43,180 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-10 02:23:43,195 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# Counting source tokens:  42%|████▏     | 10/24 [00:25<00:10,  1.32it/s]2025-04-10 02:23:45,274 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:45,305 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:45,310 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:45,317 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# Counting source tokens:  50%|█████     | 12/24 [00:25<00:06,  1.87it/s]2025-04-10 02:23:45,453 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:45,478 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:45,542 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# Counting source tokens:  67%|██████▋   | 16/24 [00:26<00:02,  3.33it/s]2025-04-10 02:23:45,671 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# Counting source tokens:  75%|███████▌  | 18/24 [00:26<00:01,  4.14it/s]2025-04-10 02:23:45,694 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:45,859 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# Counting source tokens:  83%|████████▎ | 20/24 [00:26<00:00,  4.73it/s]2025-04-10 02:23:45,960 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:46,025 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# Counting source tokens:  92%|█████████▏| 22/24 [00:26<00:00,  5.87it/s]2025-04-10 02:23:46,094 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-10 02:23:46,134 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# Counting source tokens: 100%|██████████| 24/24 [00:26<00:00,  1.12s/it]

# %%
in_loop_final = {}
offline_final = {}

# %%
BASE_CACHE_DIR = "cache/"

#experiment_groups = ["f6600ba5"] #"206f164f", "4318c7a9", "f6600ba5"]
experiment_groups = ["206f164f", "4318c7a9"]

cache_path = pathlib.Path(BASE_CACHE_DIR) / f"{'_'.join(experiment_groups)}_runs_cache.json"
api = wandb.Api() 

workspace = "ai2-llm/regmixer"

num_samples=1

group_metrics= 'all_bpb' # 'hellaswag_v2' #'arc_easy_new' #'mmlu_bpb_new' #'val_loss' #'mmlu_bpb_new'
eval_metric_group = GroupedWandbMetrics[group_metrics]
eval_metric_group_name = group_metrics

run_instances = get_runs_from_api(
        api, workspace, experiment_groups, cache_path, False, num_samples, eval_metric_group
    )
    
run_ratios = [
        {"run": run.display_name, "index": idx, **mk_weights_from_config(run.config, priors)}
        for idx, run in enumerate(run_instances)
    ]


tasks = list(run_instances[0].samples.columns)
if len(tasks) == len(eval_metric_group.value):
    tasks = eval_metric_group.value


run_metrics = []
for idx, run in enumerate(run_instances):
    if len(run.samples) == 0:
        continue 
    entry =    {
        "run": run.display_name,
        "index": idx,
        **mk_run_metrics(
            history=run.samples,
            samples=num_samples,
            metrics=(eval_metric_group_name, tasks),
            average=False,
        ),
    }
    run_metrics.append(entry)

ratios = pd.DataFrame(run_ratios)
metrics = pd.DataFrame(run_metrics)
ratios = ratios[ratios['run'].isin(metrics.run)]
# Out:
# 2025-04-10 02:24:12,789 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0009:hsbm57e5 with samples: (1, 21)
# 2025-04-10 02:24:12,792 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0003:k9k2j1ia with samples: (1, 21)
# 2025-04-10 02:24:12,795 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0006:lbimptkr with samples: (1, 21)
# 2025-04-10 02:24:12,797 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0008:j7tpz28p with samples: (1, 21)
# 2025-04-10 02:24:12,801 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0001:qevd2gzk with samples: (1, 21)
# 2025-04-10 02:24:12,805 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0007:92o2jfpg with samples: (1, 21)
# 2025-04-10 02:24:12,808 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0004:1dohri3f with samples: (1, 21)
# 2025-04-10 02:24:12,811 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0000:evt5quxd with samples: (1, 21)
# 2025-04-10 02:24:12,812 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0005:iyr8a9nn with samples: (1, 21)
# 2025-04-10 02:24:12,815 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0002:6cka8y1c with samples: (1, 21)
# 2025-04-10 02:24:12,819 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0013:4hl4ny5k with samples: (1, 21)
# 2025-04-10 02:24:12,824 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0010:bwcx9dv0 with samples: (1, 21)
# 2025-04-10 02:24:12,827 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0012:71vdehrh with samples: (1, 21)
# 2025-04-10 02:24:12,829 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0014:rk51txzz with samples: (1, 21)
# 2025-04-10 02:24:12,831 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0016:1cy0qtmy with samples: (1, 21)
# 2025-04-10 02:24:12,834 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0018:fzbca70b with samples: (1, 21)
# 2025-04-10 02:24:12,837 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0019:d5ae3zm1 with samples: (1, 21)
# 2025-04-10 02:24:12,841 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0017:gmk286my with samples: (1, 21)
# 2025-04-10 02:24:12,844 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0011:23caxgco with samples: (1, 21)
# 2025-04-10 02:24:12,846 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0015:xp1mtetu with samples: (1, 21)
# 2025-04-10 02:24:12,848 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0020:4l9qhmn8 with samples: (1, 21)
# 2025-04-10 02:24:12,851 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0022:564xym4s with samples: (1, 21)
# 2025-04-10 02:24:12,858 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0023:swuv373r with samples: (1, 21)
# 2025-04-10 02:24:12,862 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0024:7m3xaumb with samples: (1, 21)
# 2025-04-10 02:24:12,866 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0026:uvocb323 with samples: (1, 21)
# 2025-04-10 02:24:12,869 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-
- regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-5xC-30m-subset-4318c7a9-0056:81a2fghx with samples: (1, 21)
# 2025-04-10 02:24:13,578 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-5xC-30m-subset-4318c7a9-0055:yh5qnpk9 with samples: (1, 21)
# 2025-04-10 02:24:13,582 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-5xC-30m-subset-4318c7a9-0058:dfzmpmzo with samples: (1, 21)
# 2025-04-10 02:24:13,588 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-5xC-30m-subset-4318c7a9-0060:1bikzokf with samples: (1, 21)
# 2025-04-10 02:24:13,592 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-5xC-30m-subset-4318c7a9-0059:6ybio1xv with samples: (1, 21)
# 2025-04-10 02:24:13,596 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-5xC-30m-subset-4318c7a9-0061:qdp3chvy with samples: (1, 21)
# 2025-04-10 02:24:13,600 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-5xC-30m-subset-4318c7a9-0062:cfvuc7xt with samples: (1, 21)
# 2025-04-10 02:24:13,604 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-5xC-30m-subset-4318c7a9-0063:viw0bz55 with samples: (1, 21)
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished

# %%
def get_offline_results(display_name):
    bucket = 'ai2-llm'
    prefix = f'evaluation/regmixer/{display_name}_step11400-hf/'

    s3 = boto3.client('s3')

    # Get list of all files under the prefix
    paginator = s3.get_paginator('list_objects_v2')
    pages = paginator.paginate(Bucket=bucket, Prefix=prefix)

    json_files = []
    jsonl_files = []

    for page in pages:
        for obj in page.get('Contents', []):
            key = obj['Key']
            if not key.endswith('/'):
                if key.endswith('.jsonl'):
                    jsonl_files.append(key)
                elif key.endswith('.json'):
                    json_files.append(key)

    print(f"Found {len(json_files)} .json files and {len(jsonl_files)} .jsonl files.")

    all_jsonl_data = []

    for key in jsonl_files:
        if key.endswith("metrics-all.jsonl"):
            obj = s3.get_object(Bucket=bucket, Key=key)
            for line in obj['Body'].iter_lines():
                if line:
                    try:
                        data = json.loads(line.decode('utf-8'))
                        all_jsonl_data.append(data)
                    except json.JSONDecodeError as e:
                        print(f"Error decoding JSON line in {key}: {e}")

            print(f"Loaded JSONL: {key}")
            
    offline_results = {}
    for data in all_jsonl_data:

        if 'bits_per_byte_corr' in data['metrics']:
            offline_results[data['task_name']] = data['metrics']['bits_per_byte_corr']
        elif 'bits_per_byte_corr_macro' in data['metrics']:
            offline_results[data['task_name']] = data['metrics']['bits_per_byte_corr_macro']
        else:
            print(data['task_name'])
            print(data['metrics'].keys())

    return offline_results

# %%
def get_in_loop_results(metrics, display_name):
    in_loop_results = dict(sorted(metrics[metrics.run == display_name].to_dict().items()))
    return in_loop_results

# %%
display_names = ["dclm-datadelve-1xC-30m-206f164f-0114", "dclm-datadelve-1xC-30m-206f164f-0048", "dclm-datadelve-1xC-30m-206f164f-0099"]

# %%
display_names = ["dclm-datadelve-5xC-30m-subset-4318c7a9-0019", "dclm-datadelve-5xC-30m-subset-4318c7a9-0054", "dclm-datadelve-5xC-30m-subset-4318c7a9-0059"]

# %%
display_names = ["dclm-datadelve-1xC-30m-f6600ba5-0000", "dclm-datadelve-1xC-30m-f6600ba5-0001", "dclm-datadelve-1xC-30m-f6600ba5-0002", "dclm-datadelve-1xC-30m-f6600ba5-0003"]

# %%
in_loop_metrics = metrics.columns[2:].tolist()

# %%
all_in_loop_results = {}
all_offline_results = {}

for display_name in display_names:
    print(display_name)

    all_in_loop_results[display_name] = get_in_loop_results(metrics, display_name)
    all_offline_results[display_name] = get_offline_results(display_name)

    #in_loop_final[display_name] = np.array([list(value.values())[0] for name, value in in_loop_results.items() if name not in ['run', 'index']]).mean()
    #offline_final[display_name] = np.array(list(offline_results.values())).mean()
# Out:
# dclm-datadelve-5xC-30m-subset-4318c7a9-0019
# Found 78 .json files and 228 .jsonl files.
# Loaded JSONL: evaluation/regmixer/dclm-datadelve-5xC-30m-subset-4318c7a9-0019_step11400-hf/arc_challenge_rc_olmes_full-arc_easy_rc_olm-2b05f9/metrics-all.jsonl
# Loaded JSONL: evaluation/regmixer/dclm-datadelve-5xC-30m-subset-4318c7a9-0019_step11400-hf/codex_humaneval_bpb-gsm8k_olmes-mbpp_bpb-mi-93c5e5/metrics-all.jsonl
# Loaded JSONL: evaluation/regmixer/dclm-datadelve-5xC-30m-subset-4318c7a9-0019_step11400-hf/copycolors_10way_mc_none/metrics-all.jsonl
# dclm-datadelve-5xC-30m-subset-4318c7a9-0054
# Found 78 .json files and 228 .jsonl files.
# Loaded JSONL: evaluation/regmixer/dclm-datadelve-5xC-30m-subset-4318c7a9-0054_step11400-hf/arc_challenge_rc_olmes_full-arc_easy_rc_olm-2b05f9/metrics-all.jsonl
# Loaded JSONL: evaluation/regmixer/dclm-datadelve-5xC-30m-subset-4318c7a9-0054_step11400-hf/codex_humaneval_bpb-gsm8k_olmes-mbpp_bpb-mi-93c5e5/metrics-all.jsonl
# Loaded JSONL: evaluation/regmixer/dclm-datadelve-5xC-30m-subset-4318c7a9-0054_step11400-hf/copycolors_10way_mc_none/metrics-all.jsonl
# dclm-datadelve-5xC-30m-subset-4318c7a9-0059
# Found 78 .json files and 228 .jsonl files.
# Loaded JSONL: evaluation/regmixer/dclm-datadelve-5xC-30m-subset-4318c7a9-0059_step11400-hf/arc_challenge_rc_olmes_full-arc_easy_rc_olm-2b05f9/metrics-all.jsonl
# Loaded JSONL: evaluation/regmixer/dclm-datadelve-5xC-30m-subset-4318c7a9-0059_step11400-hf/codex_humaneval_bpb-gsm8k_olmes-mbpp_bpb-mi-93c5e5/metrics-all.jsonl
# Loaded JSONL: evaluation/regmixer/dclm-datadelve-5xC-30m-subset-4318c7a9-0059_step11400-hf/copycolors_10way_mc_none/metrics-all.jsonl

# %%
for i in range(len(in_loop_metrics)):

    in_loop_task = in_loop_metrics[i] 
    print(in_loop_task)

    offline = [] 
    in_loop = []
    for display_name in display_names:
        #print(display_name)
        offline_results = all_offline_results[display_name]
        in_loop_results = all_in_loop_results[display_name]




        for offline_task, offline_result in offline_results.items():

            if ":" in offline_task:
                continue 

            if offline_task in in_loop_task:
                offline.append(offline_result)
                in_loop.append(list(in_loop_results[in_loop_task].values())[0])
                print(np.abs(offline_result - list(in_loop_results[in_loop_task].values())[0]))


    from scipy.stats import spearmanr, pearsonr
    print(spearmanr(offline, in_loop)[0])
# Out:
# eval/downstream/mmlu_social_sciences_test_rc_5shot (BPB)
# nan
# eval/downstream/mmlu_humanities_test_rc_5shot (BPB)
# nan
# eval/downstream/mmlu_other_test_rc_5shot (BPB)
# nan
# eval/downstream/mmlu_stem_test_rc_5shot (BPB)
# nan
# eval/downstream/winogrande_val_rc_5shot (BPB)
# 0.2628160412999778
# 0.26228690258027254
# 0.25649253527455174
# 1.0
# eval/downstream/socialiqa_val_rc_5shot (BPB)
# 0.1422456055122876
# 0.17007637560975275
# 0.14881031327864336
# 1.0
# eval/downstream/piqa_val_rc_5shot (BPB)
# 0.039283609312411816
# 0.0420669020028579
# 0.03862640084337521
# 1.0
# eval/downstream/minerva_math_algebra_gold_bpb_0shot (BPB)
# 0.013625204508043165
# 0.015425533501968403
# 0.016213785940850656
# 1.0
# eval/downstream/minerva_math_counting_and_probability_gold_bpb_0shot (BPB)
# 0.007724095210176252
# 0.008337260193857166
# 0.009223778499173108
# 1.0
# eval/downstream/minerva_math_geometry_gold_bpb_0shot (BPB)
# 0.006049832652074372
# 0.007186449992383714
# 0.008792798906896326
# 1.0
# eval/downstream/minerva_math_intermediate_algebra_gold_bpb_0shot (BPB)
# 0.007988593777209285
# 0.008032027445665335
# 0.010100530086738058
# 1.0
# eval/downstream/minerva_math_number_theory_gold_bpb_0shot (BPB)
# 0.00907157163355743
# 0.009149376871715464
# 0.011290935007485459
# 1.0
# eval/downstream/minerva_math_prealgebra_gold_bpb_0shot (BPB)
# 0.01116398704034438
# 0.012238944381334438
# 0.013038321057155855
# 1.0
# eval/downstream/minerva_math_precalculus_gold_bpb_0shot (BPB)
# 0.007031911121589296
# 0.007261849653069863
# 0.007870955863977791
# 1.0
# eval/downstream/gsm8k_gold_bpb_5shot (BPB)
# 0.0070188959137673645
# 0.008199803636022907
# 0.008337698056662068
# 1.0
# eval/downstream/hellaswag_rc_5shot (BPB)
# 0.014038914735502006
# 0.015862805268907154
# 0.014794526242479344
# 1.0
# eval/downstream/csqa_val_rc_5shot (BPB)
# 0.2725817910094137
# 0.3140246285382826
# 0.26705084626813247
# 1.0
# eval/downstream/codex_mbpp_gold_bpb_0shot (BPB)
# 0.05470936762011558
# 0.014160423084693896
# 0.009047248408915465
# 1.0
# eval/downstream/codex_humaneval_gold_bpb_0shot (BPB)
# 0.04573579827837326
# 0.023115645537710172
# 0.018739447080405203
# 1.0
# eval/downstream/arc_easy_test_rc_5shot (BPB)
# 0.17108784808317234
# 0.17935829657395352
# 0.16648429045018176
# 1.0
# eval/downstream/arc_challenge_test_rc_5shot (BPB)
# 0.19205419671547141
# 0.19896530064841422
# 0.1862819589092768
# 1.0

# %%
offline
# Out:
# [1.8088391577004221, 1.9688668355057606, 1.8277997576281988]

# %%
in_loop
# Out:
# [2.0008933544158936, 2.167832136154175, 2.0140817165374756]

# %%
# Out:
# hellaswag eval/downstream/hellaswag_rc_5shot (BPB)
# 1.3073624167581064 1.3213847875595093

# %%
in_loop_final
# Out:
# {'dclm-datadelve-1xC-30m-f6600ba5-0000': 1.2401875257492065,
#  'dclm-datadelve-1xC-30m-f6600ba5-0001': 1.2832578420639038,
#  'dclm-datadelve-1xC-30m-f6600ba5-0002': 1.232410192489624,
#  'dclm-datadelve-1xC-30m-f6600ba5-0003': 1.3213847875595093}

# %%
offline_final
# Out:
# {'dclm-datadelve-1xC-30m-f6600ba5-0000': 1.9530376928137323,
#  'dclm-datadelve-1xC-30m-f6600ba5-0001': 1.9683715458215059,
#  'dclm-datadelve-1xC-30m-f6600ba5-0002': 1.8260503961989123,
#  'dclm-datadelve-1xC-30m-f6600ba5-0003': 2.2022111974618457}
