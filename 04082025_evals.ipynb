# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd 
import numpy as np
import os
import json
from collections import defaultdict

from scipy.stats import spearmanr, pearsonr

from regmixer.synthesize_mixture import calculate_priors
from regmixer.utils import config_from_path
from regmixer.eval.utils import (
    build_regression,
    get_output_dir,
    get_runs_from_api,
    mk_run_from_json,
    mk_run_metrics,
    mk_weights_from_config,
    mk_output_prefix,
    plot_correlation,
    simulate2,
    )


import pathlib
import wandb
import boto3


from regmixer.eval.constants import GroupedWandbMetrics


from regmixer.eval.law import ScalingLaw

# %%
bucket = 'ai2-llm'
prefix = 'evaluation/regmixer/dclm-datadelve-1xC-30m-206f164f-0114_step11400-hf/'

s3 = boto3.client('s3')

# Get list of all files under the prefix
paginator = s3.get_paginator('list_objects_v2')
pages = paginator.paginate(Bucket=bucket, Prefix=prefix)

json_files = []
jsonl_files = []

for page in pages:
    for obj in page.get('Contents', []):
        key = obj['Key']
        if not key.endswith('/'):
            if key.endswith('.jsonl'):
                jsonl_files.append(key)
            elif key.endswith('.json'):
                json_files.append(key)

print(f"Found {len(json_files)} .json files and {len(jsonl_files)} .jsonl files.")
# Out:
# Found 78 .json files and 228 .jsonl files.

# %%
all_jsonl_data = []

for key in jsonl_files:
    if key.endswith("metrics-all.jsonl"):
        obj = s3.get_object(Bucket=bucket, Key=key)
        for line in obj['Body'].iter_lines():
            if line:
                try:
                    data = json.loads(line.decode('utf-8'))
                    all_jsonl_data.append(data)
                except json.JSONDecodeError as e:
                    print(f"Error decoding JSON line in {key}: {e}")

        print(f"Loaded JSONL: {key}")
# Out:
# Loaded JSONL: evaluation/regmixer/dclm-datadelve-1xC-30m-206f164f-0114_step11400-hf/arc_challenge_rc_olmes_full-arc_easy_rc_olm-2b05f9/metrics-all.jsonl
# Loaded JSONL: evaluation/regmixer/dclm-datadelve-1xC-30m-206f164f-0114_step11400-hf/codex_humaneval_bpb-gsm8k_olmes-mbpp_bpb-mi-93c5e5/metrics-all.jsonl
# Loaded JSONL: evaluation/regmixer/dclm-datadelve-1xC-30m-206f164f-0114_step11400-hf/copycolors_10way_mc_none/metrics-all.jsonl

# %%
offline_results = {}
for data in all_jsonl_data:
    print(data['task_name'])
    try:
        print(data['metrics']['bits_per_byte_corr'])
        offline_results[data['task_name']] = data['metrics']['bits_per_byte_corr']
    except KeyError:
        print(data['metrics'])
# Out:
# mmlu:rc::olmes
# {'logits_per_token_corr_micro': -5.803046457116754, 'logits_per_token_corr_macro': -6.003525432412653, 'primary_score_micro': 0.24982196268337845, 'primary_score_macro': 0.24397789362373604, 'logits_per_char_corr_micro': -1.4047309685393543, 'logits_per_char_corr_macro': -1.553624989274837, 'acc_per_byte_micro': 0.24982196268337845, 'acc_per_byte_macro': 0.24390116003976514, 'bits_per_byte_corr_micro': 2.008864397102229, 'bits_per_byte_corr_macro': 2.217158337604244, 'acc_per_char_micro': 0.24982196268337845, 'acc_per_char_macro': 0.24397789362373604, 'sum_logits_corr_micro': -44.97763202594838, 'sum_logits_corr_macro': -43.55604781917607, 'acc_uncond_micro': 0.2590086882210511, 'acc_uncond_macro': 0.25957308084745895, 'acc_per_token_micro': 0.25373878364905283, 'acc_per_token_macro': 0.24901827502602275, 'acc_raw_micro': 0.23344252955419456, 'acc_raw_macro': 0.22929394894307456, 'primary_score': 0.24397789362373604, 'extra_metrics': {'no_answer_micro': 0.0, 'no_answer_macro': 0.0}}
# arc_challenge
# 1.9890986268092299
# arc_easy
# 1.9928398667349383
# csqa
# 2.0874815443880643
# hellaswag
# 1.486246163408497
# mmlu_abstract_algebra
# 2.7779506518258703
# mmlu_anatomy
# 2.812707969533831
# mmlu_astronomy
# 2.2434079960590596
# mmlu_business_ethics
# 2.061046225479946
# mmlu_clinical_knowledge
# 2.4280466062018573
# mmlu_college_biology
# 2.426654352678476
# mmlu_college_chemistry
# 3.9321160909684916
# mmlu_college_computer_science
# 2.891513657429193
# mmlu_college_mathematics
# 3.602777250767364
# mmlu_college_medicine
# 2.4962176196979944
# mmlu_college_physics
# 3.5302622060319977
# mmlu_computer_security
# 2.4955429175086876
# mmlu_conceptual_physics
# 2.000863212866933
# mmlu_econometrics
# 1.7939909600874742
# mmlu_electrical_engineering
# 2.7803096007811714
# mmlu_elementary_mathematics
# 3.676716109883645
# mmlu_formal_logic
# 3.9583104394192707
# mmlu_global_facts
# 2.640458204025238
# mmlu_high_school_biology
# 2.2192232337774405
# mmlu_high_school_chemistry
# 3.5435737057607772
# mmlu_high_school_computer_science
# 2.9842977944564173
# mmlu_high_school_european_history
# 1.3288663148034288
# mmlu_high_school_geography
# 1.8289825019462098
# mmlu_high_school_government_and_politics
# 1.1527223174270447
# mmlu_high_school_macroeconomics
# 1.509181629953541
# mmlu_high_school_mathematics
# 3.8725977649608856
# mmlu_high_school_microeconomics
# 1.6481893896856536
# mmlu_high_school_physics
# 2.798566134032362
# mmlu_high_school_psychology
# 1.9324553126360182
# mmlu_high_school_statistics
# 2.2096954620217195
# mmlu_high_school_us_history
# 1.2411208532067517
# mmlu_high_school_world_history
# 1.3066883719010616
# mmlu_human_aging
# 1.863327879889849
# mmlu_human_sexuality
# 2.035031435114023
# mmlu_international_law
# 1.169597306504929
# mmlu_jurisprudence
# 1.5590628108803055
# mmlu_logical_fallacies
# 1.5886692691772437
# mmlu_machine_learning
# 2.597268278827449
# mmlu_management
# 1.6557660117041249
# mmlu_marketing
# 1.8597257375255103
# mmlu_medical_genetics
# 2.8891005125707165
# mmlu_miscellaneous
# 2.605761694459916
# mmlu_moral_disputes
# 1.4727416431527103
# mmlu_moral_scenarios
# 0.8143082586384304
# mmlu_nutrition
# 2.403251803327029
# mmlu_philosophy
# 1.577406207971882
# mmlu_prehistory
# 2.115865468954549
# mmlu_professional_accounting
# 1.8564721901432544
# mmlu_professional_law
# 1.3219373974761035
# mmlu_professional_medicine
# 2.647118245547165
# mmlu_professional_psychology
# 1.6947835080989007
# mmlu_public_relations
# 1.9567159954892528
# mmlu_security_studies
# 1.1786037964205829
# mmlu_sociology
# 1.3088135696130097
# mmlu_us_foreign_policy
# 1.2329383546256318
# mmlu_virology
# 2.0736628046190866
# mmlu_world_religions
# 2.775042204894456
# piqa
# 1.8997063543209232
# socialiqa
# 1.8976898105917834
# winogrande
# 1.7062916712679714
# minerva_math::olmes
# {'exact_match_micro': 0.0, 'exact_match_macro': 0.0, 'primary_score_micro': 0.0, 'primary_score_macro': 0.0, 'exact_match_flex_micro': 0.0016, 'exact_match_flex_macro': 0.0015137590903278222, 'primary_score': 0.0}
# codex_humaneval
# 3.5119517696065197
# gsm8k
# {'exact_match_simple': 0.01819560272934041, 'exact_match': 0.01819560272934041, 'primary_score': 0.01819560272934041, 'extra_metrics': {'num_tokens': 512.0}}
# mbpp
# 4.671331863767239
# minerva_math_algebra
# {'exact_match': 0.0, 'exact_match_flex': 0.002527379949452401, 'primary_score': 0.0}
# minerva_math_counting_and_probability
# {'exact_match': 0.0, 'exact_match_flex': 0.002109704641350211, 'primary_score': 0.0}
# minerva_math_geometry
# {'exact_match': 0.0, 'exact_match_flex': 0.0, 'primary_score': 0.0}
# minerva_math_intermediate_algebra
# {'exact_match': 0.0, 'exact_match_flex': 0.0011074197120708748, 'primary_score': 0.0}
# minerva_math_number_theory
# {'exact_match': 0.0, 'exact_match_flex': 0.003703703703703704, 'primary_score': 0.0}
# minerva_math_prealgebra
# {'exact_match': 0.0, 'exact_match_flex': 0.001148105625717566, 'primary_score': 0.0}
# minerva_math_precalculus
# {'exact_match': 0.0, 'exact_match_flex': 0.0, 'primary_score': 0.0}
# copycolors:mc
# 3.042476416642343

# %%
config = "src/regmixer/config/dclm-datadelve-5xC-30m-dolma2tok.yaml"
launch_config = config_from_path(config)


priors = calculate_priors(
        source_configs=launch_config.sources,
        dtype=launch_config.dtype,
        use_cache=False,
    )
# Out:
# Counting source tokens:   0%|          | 0/24 [00:00<?, ?it/s]2025-04-08 23:24:45,235 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:24:45,301 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:24:45,317 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:24:45,329 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:24:45,349 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-08 23:24:45,402 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 8
# 2025-04-08 23:24:45,413 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 8
# 2025-04-08 23:24:46,109 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:24:46,148 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-08 23:24:46,238 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-08 23:24:46,629 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:24:46,695 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:24:46,965 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:24:47,587 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:02,481 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-08 23:25:02,488 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:02,490 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:02,493 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:02,502 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-08 23:25:02,502 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-08 23:25:02,516 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-08 23:25:03,561 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:03,575 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:03,576 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:03,577 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-08 23:25:03,583 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:03,585 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:03,586 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:03,591 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:03,599 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:04,708 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-08 23:25:04,727 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:04,744 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-08 23:25:08,419 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 3
# 2025-04-08 23:25:10,786 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:10,797 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 9
# 2025-04-08 23:25:10,819 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:10,824 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:10,826 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:10,826 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:10,827 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:10,828 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# Counting source tokens:  33%|███▎      | 8/24 [00:31<00:24,  1.56s/it]2025-04-08 23:25:14,513 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:14,523 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# Counting source tokens:  50%|█████     | 12/24 [00:31<00:08,  1.35it/s]2025-04-08 23:25:14,597 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:14,661 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:14,669 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# Counting source tokens:  62%|██████▎   | 15/24 [00:31<00:04,  2.06it/s]2025-04-08 23:25:14,724 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:14,781 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:14,846 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:14,847 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# Counting source tokens:  75%|███████▌  | 18/24 [00:31<00:02,  2.96it/s]2025-04-08 23:25:14,917 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:14,939 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:14,976 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# Counting source tokens:  92%|█████████▏| 22/24 [00:31<00:00,  4.55it/s]2025-04-08 23:25:15,039 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# 2025-04-08 23:25:15,344 - urllib3.connectionpool - WARNING - Connection pool is full, discarding connection: ai2-llm.s3.amazonaws.com. Connection pool size: 10
# Counting source tokens: 100%|██████████| 24/24 [00:32<00:00,  1.35s/it]

# %%
BASE_CACHE_DIR = "cache/"

experiment_groups = ["206f164f"]


cache_path = pathlib.Path(BASE_CACHE_DIR) / f"{'_'.join(experiment_groups)}_runs_cache.json"
api = wandb.Api() 

workspace = "ai2-llm/regmixer"

num_samples=1

group_metrics= 'all_bpb' #'arc_easy_new' #'mmlu_bpb_new' #'val_loss' #'mmlu_bpb_new'
eval_metric_group = GroupedWandbMetrics[group_metrics]
eval_metric_group_name = group_metrics

run_instances = get_runs_from_api(
        api, workspace, experiment_groups, cache_path, False, num_samples, eval_metric_group
    )
    
run_ratios = [
        {"run": run.display_name, "index": idx, **mk_weights_from_config(run.config, priors)}
        for idx, run in enumerate(run_instances)
    ]
# Out:
# 2025-04-08 23:25:43,568 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-
- regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0073:7lxtrlhb with samples: (1, 21)
# 2025-04-08 23:25:43,915 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0071:0x0b1myg with samples: (1, 21)
# 2025-04-08 23:25:43,919 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0074:k0b83rl7 with samples: (1, 21)
# 2025-04-08 23:25:43,923 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0079:fqxzt04i with samples: (1, 21)
# 2025-04-08 23:25:43,926 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0078:wfmqgsnt with samples: (1, 21)
# 2025-04-08 23:25:43,930 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0075:yk9yymf8 with samples: (1, 21)
# 2025-04-08 23:25:43,935 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0077:t8ek9z2z with samples: (1, 21)
# 2025-04-08 23:25:43,939 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0080:ghx97832 with samples: (1, 21)
# 2025-04-08 23:25:43,943 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0082:qxq9p3sc with samples: (1, 21)
# 2025-04-08 23:25:43,946 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0083:jt7igkmb with samples: (1, 21)
# 2025-04-08 23:25:43,950 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0081:4a7ttvjq with samples: (1, 21)
# 2025-04-08 23:25:43,953 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0084:fylwsy13 with samples: (1, 21)
# 2025-04-08 23:25:43,957 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0087:1k0iel2h with samples: (1, 21)
# 2025-04-08 23:25:43,965 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0086:hqa85dwo with samples: (1, 21)
# 2025-04-08 23:25:43,969 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0085:47ebf39l with samples: (1, 21)
# 2025-04-08 23:25:43,971 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0088:jc8k1itk with samples: (1, 21)
# 2025-04-08 23:25:43,973 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0090:yk1osbeo with samples: (1, 21)
# 2025-04-08 23:25:43,976 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0093:iwwyrya3 with samples: (1, 21)
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# 2025-04-08 23:25:43,981 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0094:6nz4jmao with samples: (1, 21)
# 2025-04-08 23:25:43,985 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0092:oljat221 with samples: (1, 21)
# 2025-04-08 23:25:43,988 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0091:n52v6vgn with samples: (1, 21)
# 2025-04-08 23:25:43,992 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0096:b2cmlop0 with samples: (1, 21)
# 2025-04-08 23:25:43,995 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0095:dod45l0w with samples: (1, 21)
# 2025-04-08 23:25:43,998 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0099:c7vnd43j with samples: (1, 21)
# 2025-04-08 23:25:44,002 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0122:zgbe4zed with samples: (1, 21)
# 2025-04-08 23:25:44,009 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0124:49kap6rm with samples: (1, 21)
# 2025-04-08 23:25:44,013 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0100:1bibcneo with samples: (1, 21)
# 2025-04-08 23:25:44,018 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0101:lelhivv4 with samples: (1, 21)
# 2025-04-08 23:25:44,023 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0103:dyll1q1g with samples: (1, 21)
# 2025-04-08 23:25:44,027 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0102:fehkivm5 with samples: (1, 21)
# 2025-04-08 23:25:44,034 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0104:61ov7mff with samples: (1, 21)
# 2025-04-08 23:25:44,039 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0106:w60j2aua with samples: (1, 21)
# 2025-04-08 23:25:44,043 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0107:rri99f69 with samples: (1, 21)
# 2025-04-08 23:25:44,047 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0105:0s6a88kw with samples: (1, 21)
# 2025-04-08 23:25:44,050 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0109:spxhgo01 with samples: (1, 21)
# 2025-04-08 23:25:44,056 - regmixer.eval.utils - INFO - Collected RunInstance for dclm-datadelve-1xC-30m-206f164f-0110:2r2yjqng with samples: (1, 21)
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished

# %%
run_metrics = []
for idx, run in enumerate(run_instances):
    if len(run.samples) == 0:
        continue 
    entry =    {
        "run": run.display_name,
        "index": idx,
        **mk_run_metrics(
            history=run.samples,
            samples=num_samples,
            metrics=(eval_metric_group_name, eval_metric_group.value),
            average=False,
        ),
    }
    run_metrics.append(entry)

# %%
ratios = pd.DataFrame(run_ratios)
metrics = pd.DataFrame(run_metrics)
ratios = ratios[ratios['run'].isin(metrics.run)]
